# %% [markdown]
# Import and create interface.

# %%
from gbdxtools import Interface

gbdx = Interface()

# %% [markdown]
# Next, register the task.

# %%
gbdx.task_registry.register(json_filename='../tide-task.json')
# Out:
# u'ShorelineDetectionLS8_beta:0.0.4 has been submitted for registration.'

# %% [markdown]
# Check periodically that the version just submitted has been found in the task registry.

# %%
import time
while not 'ShorelineDetectionLS8_beta:0.0.4'  in gbdx.task_registry.list():
    time.sleep(1.0)
print('done')
# Out:
# done

# %%
'ShorelineDetectionLS8_beta:0.0.4' in gbdx.task_registry.list()
# Out:
# True

# %%
gbdx.task_registry.list()
# Out:
# [u'AComp:1.1.29',
#  u'AComp:1.1.30',
#  u'AComp_0.23.2.1:0.0.1',
#  u'AOP_ENVI_HDR:0.0.1',
#  u'AOP_Strip_Processor:0.0.4',
#  u'AOP_Strip_Processor_Test:0.0.7',
#  u'AOP_Workorder:0.0.4',
#  u'AutoDTM:0.0.1',
#  u'Auto_Ordering:0.0.1',
#  u'Auto_Ordering_OR2A:0.0.5',
#  u'Build_ENVI_HDR:0.0.1',
#  u'CarDetectionPrep:0.0.1',
#  u'CarDetection_aop:0.0.1',
#  u'CarDetection_aopFixNov10:0.0.1',
#  u'CarDetection_hotfixOct32016:0.0.1',
#  u'CloudHarness_Anonymous_Task:0.0.1',
#  u'CloudOptimizedGeoTIFF:0.1.3',
#  u'CloudPuncher:0.0.1',
#  u'CompareVectors:0.0.1',
#  u'CompareVectors:0.0.2',
#  u'CompareVectors:0.0.3',
#  u'CompareVectors:0.0.4',
#  u'CompareVectors:0.0.5',
#  u'CropGeotiff:0.0.1',
#  u'CropGeotiff:0.0.2',
#  u'CropGeotiff:0.0.3',
#  u'CropGeotiff:0.0.4',
#  u'DGLayers:3.0.1',
#  u'DGLayers:3.0.2',
#  u'DGLayers:3.0.3',
#  u'DGLayers:3.0.4',
#  u'DGLayers:3.1.0',
#  u'DGLayers_v_2_0:0.0.1',
#  u'ENVI_AdditiveLeeAdaptiveFilter:1.0.2',
# ...

# %%
croptask = gbdx.Task('CropGeotiff')

# %%
croptask.definition
# Out:
# {u'containerDescriptors': [{u'command': u'java -cp crop-geotiff.jar com.digitalglobe.cropgeotiff.CropGeotiff',
#    u'properties': {u'image': u'tdgp/apps-dockers:crop-geotiff'},
#    u'type': u'DOCKER'}],
#  u'description': u'Crops input geotiff.',
#  u'inputPortDescriptors': [{u'description': u'Directory that contains geotiff to crop. Geotiff can be in subdirectory.',
#    u'name': u'data',
#    u'required': True,
#    u'type': u'directory'},
#   {u'description': u'The extents in WKT format in WGS84. Area outside of this will be excluded from result.',
#    u'multiplex': True,
#    u'name': u'wkt',
#    u'required': False,
#    u'type': u'string'},
#   {u'description': u'The shapefile to crop to.',
#    u'multiplex': True,
#    u'name': u'cutline_shapefile',
#    u'required': False,
#    u'type': u'directory'},
#   {u'description': u'The number of partitions to create. This is an alternative to setting wkt.',
#    u'name': u'num_partitions',
#    u'required': False,
# ...

# %%
cliptask = gbdx.Task('RasterClip_Extents')

# %%
cliptask.definition
# Out:
# {u'containerDescriptors': [{u'command': u'',
#    u'properties': {u'image': u'tdgp/rasterclip_extents:0.0.2'},
#    u'type': u'DOCKER',
#    u'version': u'0.0.2'}],
#  u'description': u"This is a task that requires two inputs, 'raster' and 'shp'/'wkt'/'chip_ul_lr'.  The raster will be clipped to the extent of the imagery selection area determined by the users input.  This could either be a single polygon shapefile, a polygon WKT string or an UL and LR coordinate pair that definse the area of interest.  In version 0.0.2, the XML file in the input directory is optional.  The previous version required it to be there.",
#  u'inputPortDescriptors': [{u'description': u'Name of the folder containing the geotiff file that will be clipped. Currently only supported geotiff raster image.',
#    u'name': u'raster',
#    u'required': True,
#    u'type': u'data'},
# ...
