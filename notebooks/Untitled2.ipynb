# %%
import json
from shapely.geometry import shape
with open('./bf.geojson', 'r') as f:
    js = json.load(f)

# %%
for feature in js['features']:
    s = shape(feature['geometry'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure();
ax = fig.add_subplot(111);
s
